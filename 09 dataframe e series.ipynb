# %% [markdown]
# # Basi di Serie e DataFrame

# %%
import pandas as pd

# %% [markdown]
# ## Serie
#
# *  Una serie è un elenco di valori (una lista) in colonna. La colonna non ha nome.
# *  Ogni Serie ha un *indice* che identifica ogni riga. l'indice può non essere un numero.

# %%
nani = pd.read_csv("https://github.com/gdv/python-alfabetizzazione/raw/master/data/7-nani.csv", 
                  header = None,
                  squeeze = True)

nani
# Out:
# 0    Brontolo
# 1    Cucciolo
# 2       Dotto
# 3        Eolo
# 4     Gongolo
# 5     Mammolo
# 6      Pisolo
# Name: 0, dtype: object

# %%
type(nani)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## Data Frame
#
# *  Un DataFrame è una tabella dove ogni colonna ha un nome.
# *  Un DataFrame ha un *indice* che identifica ogni riga, esattamente come una Serie.

# %%
artisti = pd.read_csv("https://github.com/tategallery/collection/raw/master/artist_data.csv")

# %%
artisti
# Out:
#          id                                               name  gender  \
# 0     10093                             Abakanowicz, Magdalena  Female
# 1         0                                Abbey, Edwin Austin    Male
# 2      2756                                   Abbott, Berenice  Female
# 3         1                             Abbott, Lemuel Francis    Male
# 4       622                                     Abrahams, Ivor    Male
# 5      2606                                            Absalon    Male
# 6      9550                                        Abts, Tomma  Female
# 7       623                                      Acconci, Vito    Male
# 8       624                                     Ackling, Roger    Male
# 9       625                                    Ackroyd, Norman    Male
# 10     2411                                       Adam, Robert    Male
# 11      626                               Adams, Harry William    Male
# 12      627                                      Adams, Norman    Male
# 13      628                                      Adams, Robert    Male
# 14      629                                    Adeney, Bernard    Male
# 15      630                                      Adler, Jankel    Male
# 16     2608                                      Adshead, Mary  Female
# 17      631                                         Adzak, Roy    Male
# 18      632                                               Afro    Male
# 19      633                                       Agar, Eileen  Female
# 20        2                            Agasse, Jacques Laurent    Male
# 21     3098                                 Ahtila, Eija-Liisa  Female
# 22     8208                                         Ai, Weiwei    Male
# 23      634                                 Aitchison, Craigie    Male
# 24      635                                   Ajmone, Giuseppe    Male
# 25    14744                                       Aksel, Erdag    Male
# 26     7794                                    Al-Ani, Jananne  Female
# 27     3067                                       Albers, Anni  Female
# 28      636                                      Albers, Josef    Male
# 29      637                                     Albright, Ivan    Male
# ...     ...                                                ...     ...
# 3502   2386                                    Yass, Catherine  Female
# 3503    619                          Yeames, William Frederick    Male
# 3504   2178                                 Yeats, Jack Butler    Male
# 3505   2179                                     Yhap, Laetitia  Female
# 3506  16784                             Yiadom-Boakye, Lynette  Female
# 3507   8297                                       Young, Carey  Female
# 3508   2180                                      Young, Robert    Male
# 3509  15539  Young-Hae Chang Heavy Industries (Young-Hae Ch...     NaN
# 3510   1326                                 Young-Hunter, John    Male
# 3511   2181                                   Yuon, Konstantin    Male
# 3512   2182                                Yvaral, Jean-Pierre    Male
# 3513  11598                                     Zaatari, Akram    Male
# 3514  13771                                    Zabala, Horacio    Male
# 3515  14306                                  Zaccagnini, Carla  Female
# 3516   2183                                         Zack, Leon    Male
# 3517   2184                                     Zadkine, Ossip    Male
# 3518   6730                           Zakanitch, Robert Rahway    Male
# 3519   2185                                        Zao, Wou-ki    Male
# 3520  14153                                        Zhang, Enli    Male
# 3521  10126                                      Ziegler, Toby    Male
# 3522  13099                           Ziolkowski, Jakub Julian     NaN
# 3523   9937                                       Zipp, Thomas    Male
# 3524   2395                                     Zittel, Andrea  Female
# 3525  13100                                   Zmijewski, Artur    Male
# 3526    620                                     Zoffany, Johan    Male
# 3527  12542                                    Zorio, Gilberto    Male
# 3528   2186                                         Zox, Larry    Male
# 3529    621                              Zuccarelli, Francesco    Male
# 3530   2187                                   Zuloaga, Ignacio    Male
# 3531   2188                                    Zyw, Aleksander    Male
#
#                  dates  yearOfBirth  yearOfDeath  \
# 0            born 1930       1930.0          NaN
# 1            1852–1911       1852.0       1911.0
# 2            1898–1991       1898.0       1991.0
# 3            1760–1803       1760.0       1803.0
# 4            born 1935       1935.0          NaN
# 5            1964–1993       1964.0       1993.0
# 6            born 1967       1967.0          NaN
# 7            born 1940       1940.0          NaN
# 8            1947–2014       1947.0       2014.0
# 9            born 1938       1938.0          NaN
# 10           1728–1792       1728.0       1792.0
# 11           1868–1947       1868.0       1947.0
# 12           1927–2005       1927.0       2005.0
# 13           1917–1984       1917.0       1984.0
# 14           1878–1966       1878.0       1966.0
# 15           1895–1949       1895.0       1949.0
# 16           1904–1995       1904.0       1995.0
# 17           1927–1987       1927.0       1987.0
# 18           1912–1976       1912.0       1976.0
# 19           1899–1991       1899.0       1991.0
# 20           1767–1849       1767.0       1849.0
# 21           born 1959       1959.0          NaN
# 22           born 1957       1957.0          NaN
# 23           1926–2009       1926.0       2009.0
# 24           1923–2005       1923.0       2005.0
# 25           born 1953       1953.0          NaN
# 26           born 1966       1966.0          NaN
# 27           1899–1994       1899.0       1994.0
# 28           1888–1976       1888.0       1976.0
# 29           1897–1983       1897.0       1983.0
# ...                ...          ...          ...
# 3502         born 1963       1963.0          NaN
# 3503         1835–1918       1835.0       1918.0
# 3504         1871–1957       1871.0       1957.0
# 3505         born 1941       1941.0          NaN
# 3506         born 1977       1977.0          NaN
# 3507         born 1970       1970.0          NaN
# 3508         born 1938       1938.0          NaN
# 3509  established 1996       1966.0          NaN
# 3510         1874–1955       1874.0       1955.0
# 3511         1875–1958       1875.0       1958.0
# 3512         1934–2002       1934.0       2002.0
# 3513         born 1966       1966.0          NaN
# 3514         born 1943       1943.0          NaN
# 3515         born 1973       1973.0          NaN
# 3516         1892–1980       1892.0       1980.0
# 3517         1890–1967       1890.0       1967.0
# 3518         born 1935       1935.0          NaN
# 3519       1921 – 2013       1921.0       2013.0
# 3520         born 1965       1965.0          NaN
# 3521         born 1972       1972.0          NaN
# 3522         born 1980       1980.0          NaN
# 3523         born 1966       1966.0          NaN
# 3524         born 1965       1965.0          NaN
# 3525         born 1966       1966.0          NaN
# 3526         1733–1810       1733.0       1810.0
# 3527         born 1944       1944.0          NaN
# 3528         born 1936       1936.0          NaN
# 3529         1702–1788       1702.0       1788.0
# 3530         1870–1945       1870.0       1945.0
# 3531         1905–1995       1905.0       1995.0
#
#                                     placeOfBirth                placeOfDeath  \
# 0                                         Polska                         NaN
# 1                    Philadelphia, United States      London, United Kingdom
# 2                     Springfield, United States       Monson, United States
# 3                 Leicestershire, United Kingdom      London, United Kingdom
# 4                          Wigan, United Kingdom                         NaN
# 5                        Tel Aviv-Yafo, Yisra'el               Paris, France
# 6                              Kiel, Deutschland                         NaN
# 7                        New York, United States                         NaN
# 8                      Isleworth, United Kingdom                         NaN
# 9                          Leeds, United Kingdom                         NaN
# 10                     Kirkcaldy, United Kingdom      London, United Kingdom
# 11                     Worcester, United Kingdom   Worcester, United Kingdom
# 12                        London, United Kingdom                         NaN
# 13                   Northampton, United Kingdom                         NaN
# 14                        London, United Kingdom                         NaN
# 15                                Tuszyn, Polska   Aldbourne, United Kingdom
# 16                        London, United Kingdom   Hampstead, United Kingdom
# 17                       Reading, United Kingdom               Paris, France
# 18                                 Udine, Italia             Zürich, Schweiz
# 19                           Ayacucho, Argentina      London, United Kingdom
# 20                               Genève, Schweiz      London, United Kingdom
# 21                            Hämeenlinna, Suomi                         NaN
# 22                             Beijing, Zhonghua                         NaN
# 23                     Edinburgh, United Kingdom                         NaN
# 24                      Carpignano Sesia, Italia                         NaN
# 25                                Izmir, Türkiye                         NaN
# 26                              Kirkuk, Al-‘Iraq                         NaN
# 27                           Berlin, Deutschland       Orange, United States
# 28                          Bottrop, Deutschland    New Haven, United States
# 29                        Chicago, United States    Woodstock, United States
# ...                                          ...                         ...
# 3502                      London, United Kingdom                         NaN
# 3503                           Taganrog, Rossiya  Teignmouth, United Kingdom
# 3504                        Down, United Kingdom     New York, United States
# 3505                Saint Albans, United Kingdom                         NaN
# 3506                      London, United Kingdom                         NaN
# 3507                              Lusaka, Zambia                         NaN
# 3508                           Vancouver, Canada                         NaN
# 3509                                         NaN                         NaN
# 3510                     Glasgow, United Kingdom         Taos, United States
# 3511                             Moskva, Rossiya             Moskva, Rossiya
# 3512                               Paris, France               Paris, France
# 3513                            Sayda, Al-Lubnan                         NaN
# 3514                     Buenos Aires, Argentina                         NaN
# 3515                     Buenos Aires, Argentina                         NaN
# 3516                   Nizhniy Novgorod, Rossiya                         NaN
# 3517                           Smolensk, Rossiya               Paris, France
# 3518                    Elizabeth, United States                         NaN
# 3519                           Beijing, Zhonghua               Nyon, Schweiz
# 3520                             Jilin, Zhonghua                         NaN
# 3521                      London, United Kingdom                         NaN
# 3522                                         NaN                         NaN
# 3523  Heppenheim an der Bergstrasse, Deutschland                         NaN
# 3524                    Sausalito, United States                         NaN
# 3525                            Warszawa, Polska                         NaN
# 3526              Frankfurt am Main, Deutschland      London, United Kingdom
# 3527                       Andorno Micca, Italia                         NaN
# 3528                   Des Moines, United States                         NaN
# 3529                                      Italia                     Firenze
# 3530                                      España                      España
# 3531                                      Polska                         NaN
#
#                                                     url
# 0     http://www.tate.org.uk/art/artists/magdalena-a...
# 1     http://www.tate.org.uk/art/artists/edwin-austi...
# 2     http://www.tate.org.uk/art/artists/berenice-ab...
# 3     http://www.tate.org.uk/art/artists/lemuel-fran...
# 4     http://www.tate.org.uk/art/artists/ivor-abraha...
# 5       http://www.tate.org.uk/art/artists/absalon-2606
# 6     http://www.tate.org.uk/art/artists/tomma-abts-...
# 7     http://www.tate.org.uk/art/artists/vito-acconc...
# 8     http://www.tate.org.uk/art/artists/roger-ackli...
# 9     http://www.tate.org.uk/art/artists/norman-ackr...
# 10    http://www.tate.org.uk/art/artists/robert-adam...
# 11    http://www.tate.org.uk/art/artists/harry-willi...
# 12    http://www.tate.org.uk/art/artists/norman-adam...
# 13    http://www.tate.org.uk/art/artists/robert-adam...
# 14    http://www.tate.org.uk/art/artists/bernard-ade...
# 15    http://www.tate.org.uk/art/artists/jankel-adle...
# 16    http://www.tate.org.uk/art/artists/mary-adshea...
# 17     http://www.tate.org.uk/art/artists/roy-adzak-631
# 18    http://www.tate.org.uk/art/artists/afro-afro-b...
# 19    http://www.tate.org.uk/art/artists/eileen-agar...
# 20    http://www.tate.org.uk/art/artists/jacques-lau...
# 21    http://www.tate.org.uk/art/artists/eija-liisa-...
# 22    http://www.tate.org.uk/art/artists/ai-weiwei-8208
# 23    http://www.tate.org.uk/art/artists/craigie-ait...
# 24    http://www.tate.org.uk/art/artists/giuseppe-aj...
# 25    http://www.tate.org.uk/art/artists/erdag-aksel...
# 26    http://www.tate.org.uk/art/artists/jananne-al-...
# 27    http://www.tate.org.uk/art/artists/anni-albers...
# 28    http://www.tate.org.uk/art/artists/josef-alber...
# 29    http://www.tate.org.uk/art/artists/ivan-albrig...
# ...                                                 ...
# 3502  http://www.tate.org.uk/art/artists/catherine-y...
# 3503  http://www.tate.org.uk/art/artists/william-fre...
# 3504  http://www.tate.org.uk/art/artists/jack-butler...
# 3505  http://www.tate.org.uk/art/artists/laetitia-yh...
# 3506  http://www.tate.org.uk/art/artists/lynette-yia...
# 3507  http://www.tate.org.uk/art/artists/carey-young...
# 3508  http://www.tate.org.uk/art/artists/robert-youn...
# 3509  http://www.tate.org.uk/art/artists/young-hae-c...
# 3510  http://www.tate.org.uk/art/artists/john-young-...
# 3511  http://www.tate.org.uk/art/artists/konstantin-...
# 3512  http://www.tate.org.uk/art/artists/jean-pierre...
# 3513  http://www.tate.org.uk/art/artists/akram-zaata...
# 3514  http://www.tate.org.uk/art/artists/horacio-zab...
# 3515  http://www.tate.org.uk/art/artists/carla-zacca...
# 3516  http://www.tate.org.uk/art/artists/leon-zack-2183
# 3517  http://www.tate.org.uk/art/artists/ossip-zadki...
# 3518  http://www.tate.org.uk/art/artists/robert-rahw...
# 3519  http://www.tate.org.uk/art/artists/zao-wou-ki-...
# 3520  http://www.tate.org.uk/art/artists/zhang-enli-...
# 3521  http://www.tate.org.uk/art/artists/toby-ziegle...
# 3522  http://www.tate.org.uk/art/artists/jakub-julia...
# 3523  http://www.tate.org.uk/art/artists/thomas-zipp...
# 3524  http://www.tate.org.uk/art/artists/andrea-zitt...
# 3525  http://www.tate.org.uk/art/artists/artur-zmije...
# 3526  http://www.tate.org.uk/art/artists/johan-zoffa...
# 3527  http://www.tate.org.uk/art/artists/gilberto-zo...
# 3528  http://www.tate.org.uk/art/artists/larry-zox-2186
# 3529  http://www.tate.org.uk/art/artists/francesco-z...
# 3530  http://www.tate.org.uk/art/artists/ignacio-zul...
# 3531  http://www.tate.org.uk/art/artists/aleksander-...
#
# [3532 rows x 9 columns]

# %% [markdown]
# ## Metodi comuni
#
# Diversi metodi sono condivisi da DataFrame e Serie. Ad esempio:
#
# *  `head` mostra le prime righe
# *  `tail` mostra le ultime righe
# *  `count` mostra il numero di righe con valori non mancanti

# %%
nani.count()
# Out:
# 7

# %% [markdown]
# ## Head e Tail
#
# Entrambi i metodi hanno un argomento opzionale che è il numero di righe da mostrare

# %%
artisti.head(4)
# Out:
#       id                    name  gender      dates  yearOfBirth  yearOfDeath  \
# 0  10093  Abakanowicz, Magdalena  Female  born 1930       1930.0          NaN
# 1      0     Abbey, Edwin Austin    Male  1852–1911       1852.0       1911.0
# 2   2756        Abbott, Berenice  Female  1898–1991       1898.0       1991.0
# 3      1  Abbott, Lemuel Francis    Male  1760–1803       1760.0       1803.0
#
#                      placeOfBirth            placeOfDeath  \
# 0                          Polska                     NaN
# 1     Philadelphia, United States  London, United Kingdom
# 2      Springfield, United States   Monson, United States
# 3  Leicestershire, United Kingdom  London, United Kingdom
#
#                                                  url
# 0  http://www.tate.org.uk/art/artists/magdalena-a...
# 1  http://www.tate.org.uk/art/artists/edwin-austi...
# 2  http://www.tate.org.uk/art/artists/berenice-ab...
# 3  http://www.tate.org.uk/art/artists/lemuel-fran...

# %%
nani.tail(2)
# Out:
# 5    Mammolo
# 6     Pisolo
# Name: 0, dtype: object

# %% [markdown]
# ## Variabili
#
# *  `shape` mostra il numero di righe e colonne
# *  `columns` è la lista delle colonne di un DataFrame
# *  `index` è l'indice del DataFrame

# %%
artisti.shape
# Out:
# (3532, 9)

# %%
artisti.columns
# Out:
# Index(['id', 'name', 'gender', 'dates', 'yearOfBirth', 'yearOfDeath',
#        'placeOfBirth', 'placeOfDeath', 'url'],
#       dtype='object')

# %% [markdown]
# Nel caso di una Serie, la `shape` può riportare solo il numero di righe.

# %%
nani.shape
# Out:
# (7,)

# %% [markdown]
# ## Indice
#
# L'indice è memorizzato nella variabile `index` del DataFrame o della Serie

# %%
nani.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %% [markdown]
# La variabile `values` memorizza i valori del DataFrame

# %%
artisti.values
# Out:
# array([[10093, 'Abakanowicz, Magdalena', 'Female', ..., 'Polska', nan,
#         'http://www.tate.org.uk/art/artists/magdalena-abakanowicz-10093'],
#        [0, 'Abbey, Edwin Austin', 'Male', ...,
#         'Philadelphia, United States', 'London, United Kingdom',
#         'http://www.tate.org.uk/art/artists/edwin-austin-abbey-0'],
#        [2756, 'Abbott, Berenice', 'Female', ...,
#         'Springfield, United States', 'Monson, United States',
#         'http://www.tate.org.uk/art/artists/berenice-abbott-2756'],
#        ...,
#        [621, 'Zuccarelli, Francesco', 'Male', ..., 'Italia', 'Firenze',
#         'http://www.tate.org.uk/art/artists/francesco-zuccarelli-621'],
#        [2187, 'Zuloaga, Ignacio', 'Male', ..., 'España', 'España',
#         'http://www.tate.org.uk/art/artists/ignacio-zuloaga-2187'],
#        [2188, 'Zyw, Aleksander', 'Male', ..., 'Polska', nan,
#         'http://www.tate.org.uk/art/artists/aleksander-zyw-2188']],
#       dtype=object)

# %% [markdown]
# ## Estrarre campioni
#
# Per estrarre un insieme casuale di righe da un DataFrame, si può usare il metodo `sample` che vuole il numero di righe da estrarre.

# %%
artisti.sample(3)
# Out:
#          id              name  gender      dates  yearOfBirth  yearOfDeath  \
# 1910  13769      Leirner, Jac  Female  born 1961       1961.0          NaN
# 2654   1824  Reid, Sir Norman    Male  1915–2007       1915.0       2007.0
# 1742   2764     Klein, Jochen    Male  1967–1997       1967.0       1997.0
#
#                    placeOfBirth            placeOfDeath  \
# 1910          São Paulo, Brasil                     NaN
# 2654  Edinburgh, United Kingdom  London, United Kingdom
# 1742                        NaN                     NaN
#
#                                                     url
# 1910  http://www.tate.org.uk/art/artists/jac-leirner...
# 2654  http://www.tate.org.uk/art/artists/sir-norman-...
# 1742  http://www.tate.org.uk/art/artists/jochen-klei...

# %% [markdown]
# In questo caso, ogni esecuzione del comando sopra produrrà un risultato diverso dal precedente. Normalmente ripetere l'esecuzione di uno stesso comando produce sempre lo stesso risultato.

# %% [markdown]
# ## Estrarre colonne da un DataFrame
#
# Estrarre una colonna equivale a costruire una serie. Notare che la colonna dei dati non ha nome, ma c'è un indice.

# %%
artisti["name"].head(3)
# Out:
# 0    Abakanowicz, Magdalena
# 1       Abbey, Edwin Austin
# 2          Abbott, Berenice
# Name: name, dtype: object

# %% [markdown]
# Selezionare un insieme di colonne. Notare le doppie parentesi quadre: quelle esterne rappresentano l'estrazione di colonne, quelle interne creano una lista di colonne.

# %%
artisti[["name", "placeOfBirth", "yearOfBirth"]]
artisti.head(3)
# Out:
#       id                    name  gender      dates  yearOfBirth  yearOfDeath  \
# 0  10093  Abakanowicz, Magdalena  Female  born 1930       1930.0          NaN
# 1      0     Abbey, Edwin Austin    Male  1852–1911       1852.0       1911.0
# 2   2756        Abbott, Berenice  Female  1898–1991       1898.0       1991.0
#
#                   placeOfBirth            placeOfDeath  \
# 0                       Polska                     NaN
# 1  Philadelphia, United States  London, United Kingdom
# 2   Springfield, United States   Monson, United States
#
#                                                  url
# 0  http://www.tate.org.uk/art/artists/magdalena-a...
# 1  http://www.tate.org.uk/art/artists/edwin-austi...
# 2  http://www.tate.org.uk/art/artists/berenice-ab...

# %% [markdown]
# ## Cancellare colonne da un DataFrame
#
# Per cancellare una colonna, bisogna usare il comando `del`. Nell'esempio che segue, cancelleremo la colonna `url` del DataFrame `artisti`.

# %%
del(artisti['url'])

# %%
artisti.columns
# Out:
# Index(['id', 'name', 'gender', 'dates', 'yearOfBirth', 'yearOfDeath',
#        'placeOfBirth', 'placeOfDeath'],
#       dtype='object')

# %% [markdown]
# Bisogna fare attenzione all'utilizzo di `del`. Mentre quasi tutte le operazioni su DataFrame che vedremo **creano** un nuovo DataFrame, l'operazione `del` cancella effettivamente la colonna del DataFrame.
#
# Questa operazione non è invertibile. Se si esegue una `del` per errore, bisogna ricreare il DataFrame.

# %% [markdown]
# # Indice

# %% [markdown]
# ## Indice
#
# Di solito l'indice viene utilizzato per identificare ogni riga di un DataFrame (o Serie), ma in realtà ciò non è garantito (a differenza di una chiave in una tabella).
#
# Un indice può essere visto come:
# *  una lista immutabile;
# *  un insieme ordinato.
#
# Spesso l'indice è formato da una sequenza di numeri interi consecutivi: in questo caso vedremo che l'indice ha tipo `RangeIndex`. Ad esempio, andiamo a vedere l'indice di `nani`:

# %%
indice = nani.index
indice
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %% [markdown]
# In generale l'indice è formato da elementi arbitrari. In questo caso vediamo la lista dei valori.

# %%
artisti.sample(3).index
# Out:
# Int64Index([2518, 8, 1278], dtype='int64', name='id')

# %% [markdown]
# ## Accedere a parti dell'indice
#
# Siccome un indice è una lista, è possibile accedere a elementi o porzioni dell'indice usando la notazione usuale delle liste.

# %%
indice[3]
# Out:
# 3

# %%
indice[2:5]
# Out:
# RangeIndex(start=2, stop=5, step=1)

# %% [markdown]
# Ma non è possibile modificare elementi dell'indice (è immutabile)

# %%
indice[4] = 'Biancaneve'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-81-36a3b51886e0> in <module>
# ----> 1 indice[4] = 'Biancaneve'
#
# ~/.miniconda/lib/python3.6/site-packages/pandas/core/indexes/base.py in __setitem__(self, key, value)
#    2063
#    2064     def __setitem__(self, key, value):
# -> 2065         raise TypeError("Index does not support mutable operations")
#    2066
#    2067     def __getitem__(self, key):
#
# TypeError: Index does not support mutable operations

# %% [markdown]
# ## Estrarre righe da un DataFrame: da un indice
#
# E' possibile estrarre righe sfruttando:
# 1.  l'indice implicito (non ha un nome) con la `iloc` (la *i* significa *implicito*)
# 2.  l'indice esplicito con la `loc`
#
# Vediamo adesso più in dettaglio il concetto di indice *implicito*. Un DataFrame può essere visto come una lista di righe. In questo caso l'indice implicito è esattamente l'indice di questa lista: inizia con 0 e termina con il numero di righe meno 1.
#
# Siccome il DataFrame viene visto come una lista, posso accedere a elementi o insiemi di righe usando le espressioni tipiche delle liste, però usando il metodo `iloc`.

# %%
artisti.iloc[0]
# Out:
# name                    Abbey, Edwin Austin
# gender                                 Male
# dates                             1852–1911
# yearOfBirth                            1852
# yearOfDeath                            1911
# placeOfBirth    Philadelphia, United States
# placeOfDeath         London, United Kingdom
# età                                      59
# Name: 0, dtype: object

# %%
artisti.iloc[3:5]
# Out:
#                        name gender      dates  yearOfBirth  yearOfDeath  \
# id
# 1    Abbott, Lemuel Francis   Male  1760–1803       1760.0       1803.0
# 622          Abrahams, Ivor   Male  born 1935       1935.0          NaN
#
#                        placeOfBirth            placeOfDeath
# id
# 1    Leicestershire, United Kingdom  London, United Kingdom
# 622           Wigan, United Kingdom                     NaN

# %% [markdown]
# Notare che, esattamente come nelle liste, quando si estrae una slice l'ultimo elemento indicato è escluso dal risultato.

# %% [markdown]
# ## Indice esplicito
#
# L'indice *esplicito* è invece quello corrispondente al metodo `index`. In questo modo, usando il metodo `loc` è possibile estrarre:
# *  una singola riga
# *  un insieme di righe (l'insieme viene specificato con una lista

# %%
artisti.loc[6]
# Out:
# name            Alma-Tadema, Sir Lawrence
# gender                               Male
# dates                           1836–1912
# yearOfBirth                          1836
# yearOfDeath                          1912
# placeOfBirth          Dronrijp, Nederland
# placeOfDeath       Wiesbaden, Deutschland
# età                                    76
# Name: 6, dtype: object

# %%
artisti.loc[[3, 4, 5]]
# Out:
#                      name gender      dates  yearOfBirth  yearOfDeath  \
# id
# 3     Alken, Henry Thomas   Male  1785–1851       1785.0       1851.0
# 4      Allan, Sir William   Male  1782–1850       1782.0       1850.0
# 5   Allen, Joseph William   Male  1803–1852       1803.0       1852.0
#
#                  placeOfBirth               placeOfDeath
# id
# 3      London, United Kingdom     London, United Kingdom
# 4   Edinburgh, United Kingdom  Edinburgh, United Kingdom
# 5     Lambeth, United Kingdom     London, United Kingdom

# %% [markdown]
# Notare che l'ultima `loc` presenta due coppie di parentesi quadre: la coppia esterna è dovuta al fatto che `loc` vuole gli argomenti fra parentesi quadre (è un indizio mnemonico per ricordare che accedo ad una parte dei dati), mentre la coppia interna è la sintassi che specifica che si tratta di una lista.

# %% [markdown]
# ## Indice esplicito: slice
#
# Quando accediamo a porzioni di liste, una delle modalità più frequenti è lo slice: in questo caso specifichiamo una porzione di DataFrame identificata dal suo inizio e dalla sua fine.
#
# L'utilizzo di uno slice con la `loc` ha due particolarità:
# 1.  Per usare la `loc` con uno slice, è necessario prima ordinare il DataFrame rispetto all'indice, con la `sort_index` (eventualmente con `inplace = True` se non desideriamo creare un nuovo DataFrame);
# 2.  il risultato includerà *entrambi* gli estremi indicati nello slice (mentre con l'indice implicito, il risultato di uno slice non include l'estremo finale).

# %%
artisti.sort_index(inplace = True)

# %%
artisti.loc[3:5]
# Out:
#                      name gender      dates  yearOfBirth  yearOfDeath  \
# id
# 3     Alken, Henry Thomas   Male  1785–1851       1785.0       1851.0
# 4      Allan, Sir William   Male  1782–1850       1782.0       1850.0
# 5   Allen, Joseph William   Male  1803–1852       1803.0       1852.0
#
#                  placeOfBirth               placeOfDeath   età
# id
# 3      London, United Kingdom     London, United Kingdom  66.0
# 4   Edinburgh, United Kingdom  Edinburgh, United Kingdom  68.0
# 5     Lambeth, United Kingdom     London, United Kingdom  49.0

# %% [markdown]
# Possiamo verificare immediatamente che il risultato della `loc` include la riga con indice 5.

# %% [markdown]
# ## Determinare l'indice del DataFrame
#
# Talvolta abbiamo un DataFrame in cui una colonna è adatta ad essere un indice esplicito migliore di quello di default (l'indice implicito, formato da una sequenza di numeri a partire da 0).
#
# Per trasformare una colonna in indice è necessario assegnare il risultato di `set_index` ad un nuovo DataFrame.
# Notare che anche questa operazione crea un nuovo DataFrame.

# %%
artisti = artisti.set_index("id")
artisti.head(3)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.miniconda/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'id'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-88-561a3fa19942> in <module>
# ----> 1 artisti = artisti.set_index("id")
#       2 artisti.head(3)
#
# ~/.miniconda/lib/python3.6/site-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    3907                 names.append(None)
#    3908             else:
# -> 3909                 level = frame[col]._values
#    3910                 names.append(col)
#    3911                 if drop:
#
# ~/.miniconda/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# ~/.miniconda/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# ~/.miniconda/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# ~/.miniconda/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~/.miniconda/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'id'

# %% [markdown]
# ## Decidere l'indice durante la lettura
#
# Leggendo il DataFrame con `read_csv` o `read_json` è possibile selezionare una colonna come indice, utilizzando l'opzione `index_col`.

# %%
artisti2 = pd.read_csv("https://github.com/tategallery/collection/raw/master/artist_data.csv",
                      index_col = "id")

# %%
artisti.head(3)
# Out:
#                          name  gender      dates  yearOfBirth  yearOfDeath  \
# id
# 10093  Abakanowicz, Magdalena  Female  born 1930       1930.0          NaN
# 0         Abbey, Edwin Austin    Male  1852–1911       1852.0       1911.0
# 2756         Abbott, Berenice  Female  1898–1991       1898.0       1991.0
#
#                       placeOfBirth            placeOfDeath
# id
# 10093                       Polska                     NaN
# 0      Philadelphia, United States  London, United Kingdom
# 2756    Springfield, United States   Monson, United States

# %% [markdown]
# Bisogna però capire se è più utile avere una variabile identificativa oppure un indice:
#
# *  l'indice permette un accesso veloce alle righe, soprattutto tramite uno slice
# *  alcune funzionalità (ad esempio la `groupby` che vedremo più avanti) sono possibili solo con le colonne.

# %% [markdown]
# ## Resettare l'indice
#
# Per alcune operazioni, diventa utile trasformare l'indice in una colonna, ottenendo un nuovo DataFrame.
# Notare che il risultato di questa operazione è sempre un DataFrame, anche a partire da una Serie.
#
# L'istruzione necessaria è `reset_index`

# %%
artisti3 = artisti.reset_index()
artisti3.head(6)
# Out:
#       id                    name  gender      dates  yearOfBirth  yearOfDeath  \
# 0  10093  Abakanowicz, Magdalena  Female  born 1930       1930.0          NaN
# 1      0     Abbey, Edwin Austin    Male  1852–1911       1852.0       1911.0
# 2   2756        Abbott, Berenice  Female  1898–1991       1898.0       1991.0
# 3      1  Abbott, Lemuel Francis    Male  1760–1803       1760.0       1803.0
# 4    622          Abrahams, Ivor    Male  born 1935       1935.0          NaN
# 5   2606                 Absalon    Male  1964–1993       1964.0       1993.0
#
#                      placeOfBirth            placeOfDeath
# 0                          Polska                     NaN
# 1     Philadelphia, United States  London, United Kingdom
# 2      Springfield, United States   Monson, United States
# 3  Leicestershire, United Kingdom  London, United Kingdom
# 4           Wigan, United Kingdom                     NaN
# 5         Tel Aviv-Yafo, Yisra'el           Paris, France

# %% [markdown]
# # Gestione DataFrame

# %% [markdown]
# ## Fancy indexing
#
# In precedenza abbiamo visto come estrarre alcune righe da un DataFrame sfruttando l'indice (sia esplicito che implicito).
#
# Una modalità più sofisticata per estrarre righe consiste nel *fancy indexing* dove viene fornito un array booleano di lunghezza pari al numero di righe del DataFrame. L'array booleano viene utilizzato al posto dell'indice e il risultato è formato dalle righe nelle posizioni vere (`True` dell'array).
#
# Vediamo un esempio sulla Serie `nani` che ha 7 elementi. Costruiamo una lista di 7 booleani dove i valori veri sono in posizione 0, 3, 6.

# %%
lista = [ True, False, False, True, False, False, True]

# %% [markdown]
# Il risultato del fancy indexing con argomento `lista` corrisponde alle righe in posizione 0, 3, 6 di nani.

# %%
nani[lista]
# Out:
# 0    Brontolo
# 3        Eolo
# 6      Pisolo
# Name: 0, dtype: object

# %% [markdown]
# ## Estrarre righe da un DataFrame: con una condizione
#
# Il fancy indexing avrebbe utilità molto limitata se dovessimo costruire esplicitamente l'array booleano.
#
# Possiamo costruirlo scrivendo una condizione sui valori. Ciò permette di selezionare con facilità tutte le righe del DataFrame che soddisfano una condizione.
#
# Come esempio, selezioniamo gli artisti che sono donne. Scriviamo inizialmente la condizione che è vera se il valore della colonna `gender` è `True`.

# %%
artisti['gender'] == 'Female'
# Out:
# id
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
# 30       False
#          ...
# 17135    False
# 17138    False
# 17194     True
# 17197    False
# 17198    False
# 17201    False
# 17224    False
# 17320    False
# 17408     True
# 17410     True
# 17412    False
# 17414     True
# 17422     True
# 17450    False
# 17656    False
# 17732    False
# 17882    False
# 17924    False
# 18070    False
# 18071    False
# 18242    False
# 18243    False
# 18244    False
# 18264    False
# 18265    False
# 18266    False
# 18267    False
# 18317     True
# 18372    False
# 18896    False
# Name: gender, Length: 3532, dtype: bool

# %% [markdown]
# Il fatto che `dtype` vale `bool` indica che abbiamo effettivamente costruito un array booleano.

# %% [markdown]
# ## Estrarre righe da un DataFrame: con una condizione (2)
#
# Adesso possiamo sfruttare la condizione scritta in precedenza per estrarre le righe interessanti.
#
# Dobbiamo solo usare l'array come se fosse un indice.

# %%
artisti[artisti['gender'] == 'Female']
# Out:
#                                          name  gender        dates  \
# id
# 71                          Butler, Elizabeth  Female    1846–1933
# 72                       Butler, Mildred Anne  Female    1858–1941
# 189                         Forbes, Elizabeth  Female    1859–1912
# 219                                 Gow, Mary  Female    1851–1929
# 303                        Kauffman, Angelica  Female    1741–1807
# 361                       Macdonald, Georgina  Female    1840–1920
# 378                         Merritt, Anna Lea  Female    1844–1930
# 467               Rutland, Violet, Duchess of  Female    1856–1937
# 494                 Siddal, Elizabeth Eleanor  Female    1829–1862
# 517                          Spilsbury, Maria  Female  1777–c.1823
# 520                     Stanley, Lady Dorothy  Female    1855–1926
# 528                          Stokes, Marianne  Female    1855–1927
# 540                  Swynnerton, Annie Louisa  Female    1844–1933
# 582    Waterford, Louisa Anne, Marchioness of  Female    1818–1891
# 593                        Wells, Joanna Mary  Female    1831–1861
# 633                              Agar, Eileen  Female    1899–1991
# 641                      Allan, Julian Phelps  Female    1892–1996
# 642                             Alley, Anthea  Female    1927–1993
# 674                             Atwood, Clare  Female    1866–1962
# 680                        Ayres, OBE Gillian  Female    born 1930
# 684                                  Baer, Jo  Female    born 1929
# 694                          Barker, Margaret  Female    born 1907
# 697                  Barns-Graham, Wilhelmina  Female    1912–2004
# 698                        Bartlett, Jennifer  Female    born 1941
# 728                        Bell, Laura Anning  Female    1867–1950
# 731                             Bell, Vanessa  Female    1879–1961
# 735                  Bellingham-Smith, Elinor  Female    1906–1988
# 739                             Benois, Nadia  Female    1896–1975
# 759                             Black, Sheila  Female          NaN
# 760                     Blackadder, Elizabeth  Female    born 1931
# ...                                       ...     ...          ...
# 14735                 Choucair, Saloua Raouda  Female    born 1916
# 14791                            Reid, Clunie  Female    born 1971
# 14881                            Davey, Moyra  Female    born 1958
# 14889                            Kher, Bharti  Female    born 1969
# 14953                            Barrada, Yto  Female    born 1971
# 14983                               Dadamaino  Female    1930–2004
# 14997                        Tompkins, Hayley  Female    born 1971
# 15125                            Martin, Anne  Female    born 1936
# 15351                       Chernysheva, Olga  Female    born 1962
# 15549                         Cluett, Shelagh  Female    1947–2007
# 15589                            Stern, Grete  Female    1904–1999
# 15851                          Errazuriz, Paz  Female    born 1944
# 15930                     Karamustafa, Gulsun  Female    born 1946
# 15931                             Yalter, Nil  Female    born 1938
# 15999                         Biermann, Aenne  Female    1893–1933
# 16111                             Rhodes, Lis  Female    born 1942
# 16113                            Cohen, Lynne  Female    born 1944
# 16115                 Schulz-Dornburg, Ursula  Female    born 1938
# 16385                             Raven, Lucy  Female    born 1977
# 16443                     Perriand, Charlotte  Female    1903–1999
# 16467         Shahroudy Farmanfarmaian, Monir  Female    born 1924
# 16784                  Yiadom-Boakye, Lynette  Female    born 1977
# 16798                           Sterne, Hedda  Female    1910–2011
# 16982                            Sillman, Amy  Female    born 1966
# 17194                          Hashmi, Zarina  Female    born 1937
# 17408                         Thuring, Caragh  Female    born 1972
# 17410                       Yarrow, Catherine  Female    1904–1990
# 17414                       Fukushima, Hideko  Female    1927–1997
# 17422                             Wylie, Rose  Female    born 1934
# 18317                        Monteiro, Anjali  Female          NaN
#
#        yearOfBirth  yearOfDeath                      placeOfBirth  \
# id
# 71          1846.0       1933.0                 Lausanne, Schweiz
# 72          1858.0       1941.0                  Thomastown, Éire
# 189         1859.0       1912.0                    Ottawa, Canada
# 219         1851.0       1929.0            London, United Kingdom
# 303         1741.0       1807.0                     Chur, Schweiz
# 361         1840.0       1920.0                               NaN
# 378         1844.0       1930.0       Philadelphia, United States
# 467         1856.0       1937.0             Wigan, United Kingdom
# 494         1829.0       1862.0            London, United Kingdom
# 517         1777.0       1823.0            London, United Kingdom
# 520         1855.0       1926.0            London, United Kingdom
# 528         1855.0       1927.0                  Graz, Österreich
# 540         1844.0       1933.0        Manchester, United Kingdom
# 582         1818.0       1891.0                     Paris, France
# 593         1831.0       1861.0                               NaN
# 633         1899.0       1991.0               Ayacucho, Argentina
# 641         1892.0       1996.0       Southampton, United Kingdom
# 642         1927.0       1993.0                Seremban, Malaysia
# 674         1866.0       1962.0          Richmond, United Kingdom
# 680         1930.0          NaN            London, United Kingdom
# 684         1929.0          NaN            Seattle, United States
# 694         1907.0          NaN          Sydenham, United Kingdom
# 697         1912.0       2004.0     Saint Andrews, United Kingdom
# 698         1941.0          NaN         Long Beach, United States
# 728         1867.0       1950.0                            France
# 731         1879.0       1961.0        Kensington, United Kingdom
# 735         1906.0       1988.0            London, United Kingdom
# 739         1896.0       1975.0          Sankt-Peterburg, Rossiya
# 759            NaN          NaN                               NaN
# 760         1931.0          NaN           Falkirk, United Kingdom
# ...            ...          ...                               ...
# 14735       1916.0          NaN                 Bayrut, Al-Lubnan
# 14791       1971.0          NaN           Pembury, United Kingdom
# 14881       1958.0          NaN                   Toronto, Canada
# 14889       1969.0          NaN            London, United Kingdom
# 14953       1971.0          NaN                     Paris, France
# 14983       1935.0       2004.0                    Milano, Italia
# 14997       1971.0          NaN  Leighton Buzzard, United Kingdom
# 15125       1936.0          NaN            London, United Kingdom
# 15351       1962.0          NaN                   Moskva, Rossiya
# 15549       1947.0       2007.0       Bournemouth, United Kingdom
# 15589       1904.0       1999.0                       Deutschland
# 15851       1944.0          NaN                   Santiago, Chile
# 15930       1946.0          NaN                           Türkiye
# 15931       1938.0          NaN                  Al-Qahirah, Misr
# 15999       1893.0       1933.0                 Goch, Deutschland
# 16111       1942.0          NaN            London, United Kingdom
# 16113       1944.0          NaN             Racine, United States
# 16115       1938.0          NaN               Berlin, Deutschland
# 16385       1977.0          NaN                               NaN
# 16443       1903.0       1999.0                     Paris, France
# 16467       1924.0          NaN                      Qazvin, Îran
# 16784       1977.0          NaN            London, United Kingdom
# 16798       1910.0       2011.0                Bucuresti, România
# 16982       1966.0          NaN            Detroit, United States
# 17194       1937.0          NaN                   Aligarh, Bharat
# 17408       1972.0          NaN                 Bruxelles, België
# 17410       1904.0       1990.0         Harpenden, United Kingdom
# 17414       1927.0       1997.0                               NaN
# 17422       1934.0          NaN             Hythe, United Kingdom
# 18317          NaN          NaN                               NaN
#
#                               placeOfDeath    età
# id
# 71                                    Éire   87.0
# 72                        Thomastown, Éire   83.0
# 189                 Newlyn, United Kingdom   53.0
# 219                 London, United Kingdom   78.0
# 303                           Roma, Italia   66.0
# 361                                    NaN   80.0
# 378    Hurstbourne Tarrant, United Kingdom   86.0
# 467                 London, United Kingdom   81.0
# 494                 London, United Kingdom   33.0
# 517                                   Éire   46.0
# 520                 London, United Kingdom   71.0
# 528                 London, United Kingdom   72.0
# 540         Hayling Island, United Kingdom   89.0
# 582                   Ford, United Kingdom   73.0
# 593                 London, United Kingdom   30.0
# 633                 London, United Kingdom   92.0
# 641                                    NaN  104.0
# 642                                    NaN   66.0
# 674              Tenterden, United Kingdom   96.0
# 680                                    NaN    NaN
# 684                                    NaN    NaN
# 694                                    NaN    NaN
# 697                                    NaN   92.0
# 698                                    NaN    NaN
# 728                 London, United Kingdom   83.0
# 731            West Sussex, United Kingdom   82.0
# 735                Ipswich, United Kingdom   82.0
# 739        Gloucestershire, United Kingdom   79.0
# 759                                    NaN    NaN
# 760                                    NaN    NaN
# ...                                    ...    ...
# 14735                                  NaN    NaN
# 14791                                  NaN    NaN
# 14881                                  NaN    NaN
# 14889                                  NaN    NaN
# 14953                                  NaN    NaN
# 14983                                  NaN   69.0
# 14997                                  NaN    NaN
# 15125                                  NaN    NaN
# 15351                                  NaN    NaN
# 15549               London, United Kingdom   60.0
# 15589              Buenos Aires, Argentina   95.0
# 15851                                  NaN    NaN
# 15930                                  NaN    NaN
# 15931                                  NaN    NaN
# 15999                    Gera, Deutschland   40.0
# 16111                                  NaN    NaN
# 16113                                  NaN    NaN
# 16115                                  NaN    NaN
# 16385                                  NaN    NaN
# 16443                        Paris, France   96.0
# 16467                                  NaN    NaN
# 16784                                  NaN    NaN
# 16798      Manhattan Island, United States  101.0
# 16982                                  NaN    NaN
# 17194                                  NaN    NaN
# 17408                                  NaN    NaN
# 17410                                  NaN   86.0
# 17414                                  NaN   70.0
# 17422                                  NaN    NaN
# 18317                                  NaN    NaN
#
# [521 rows x 8 columns]

# %% [markdown]
# Nell'istruzione dobbiamo scrivere due volte `artisti`: la prima volta è perchè vogliamo estrarre righe dal DataFrame `artisti`, la seconda per costruire la condizione.
#
# Non è obbligatorio che il DataFrame coinvolto nella condizione sia lo stesso da cui estrarre le righe: l'unica condizione è che l'array usato come indice abbia tanti elementi quante sono le righe del DataFrame di cui vogliamo selezionare le righe.

# %% [markdown]
# ## Estrarre righe con condizioni composte
#
# Le condizioni composte richiedono l'uso di `~` (not), `|` (or), `&` (and). Non è possibile utilizzare le parole riservate di Python `and`, `or` e `not` per una questione tecnica.
#
# Inoltre alcune condizioni devono essere racchiuse fra parentesi per evitare problemi di precedenza degli operatori. Per evitare possibili confusioni, si raccomanda di racchiudere *sempre* le condizioni fra parentesi.

# %%
artisti[(artisti['gender'] == 'Female') & 
        (artisti['yearOfBirth'] >= 1731) &
        (artisti['yearOfBirth'] <= 1800)]
# Out:
#                                                    name  gender        dates  \
# id
# 303                                  Kauffman, Angelica  Female    1741–1807
# 517                                    Spilsbury, Maria  Female  1777–c.1823
# 2523                        Percy, Lady Susan Elizabeth  Female    1782–1847
# 2539                                       Sanders, Ann  Female  active 1778
# 2544                                    Wheatley, Clara  Female  c.1750–1838
# 2553                                Damer, Anne Seymour  Female    1748–1828
# 2570                                       Long, Amelia  Female    1772–1837
# 2573                                     Scott, Frances  Female    1750–1817
# 2575  Sutherland, Elizabeth Leveson-Gower, Duchess-C...  Female    1765–1839
# 2576                                  Wharncliffe, Lady  Female  c.1776–1853
# 2577                                       Gordon, Lady  Female    1775–1867
#
#       yearOfBirth  yearOfDeath               placeOfBirth  \
# id
# 303        1741.0       1807.0              Chur, Schweiz
# 517        1777.0       1823.0     London, United Kingdom
# 2523       1782.0       1847.0                        NaN
# 2539       1778.0       1778.0                        NaN
# 2544       1750.0       1838.0                        NaN
# 2553       1748.0       1828.0  Sundridge, United Kingdom
# 2570       1772.0       1837.0     London, United Kingdom
# 2573       1750.0       1817.0                        NaN
# 2575       1765.0       1839.0                        NaN
# 2576       1776.0       1853.0                        NaN
# 2577       1775.0       1867.0                        NaN
#
#                 placeOfDeath   età
# id
# 303             Roma, Italia  66.0
# 517                     Éire  46.0
# 2523                     NaN  65.0
# 2539                     NaN   0.0
# 2544  London, United Kingdom  88.0
# 2553  London, United Kingdom  80.0
# 2570    Kent, United Kingdom  65.0
# 2573                     NaN  67.0
# 2575                     NaN  74.0
# 2576                     NaN  77.0
# 2577                     NaN  92.0

# %% [markdown]
# ## Valori mancanti
#
# In Python i valori mancanti sono rappresentanti con `None`. In Pandas possono anche essere rappresentati da `numpy.nan`: in questo caso è necessario importare la libreria `numpy`.
#
# Inoltre bisogna capire come i valori mancanti sono rappresentati nel dataset, perchè talvolta si preferisce avere un valore (detto *sentinella*) ritenuto impossibile che rappresenta in realtà il fatto che il valore è mancante. Ad esempio una data nell'anno 9999, oppure una temperatura -999.
#
# Questi casi vanno gestiti con attenzione perchè è necessario capire la natura dei dati da trattare. Pandas non può aiutarci, perchè non è possibile trovare una soluzione che sia sempre corretta.

# %%
istituti = pd.read_csv("https://www.dati.lombardia.it/api/views/99k2-qg4v/rows.csv?accessType=DOWNLOAD", 
                       sep = ',')
istituti.head(3)
# Out:
#                            DENOMINAZIONE RETTORE_DIRETTORE         INDIRIZZO  \
# 0     UNIVERSITA' DEGLI STUDI DI BERGAMO   Stefano Paleari    Via Salvecchio
# 1       UNIVERSITA' DEGLI STUDI DI PAVIA       Fabio Rugge      Strada Nuova
# 2  UNIVERSITA' CATTOLICA DEL SACRO CUORE     Franco Anelli  Largo A. Gemelli
#
#      CAP   COMUNE  CIVICO               EMAIL        TELEFONO          FAX  \
# 0  24100  Bergamo      19    rettore@unibg.it     035-2052242   035-243054
# 1  27100    Pavia      65    rettore@unipv.it  0382/984201-02  0382/984633
# 2  20123   Milano       1  rettore@unicatt.it     02-72342288  02-72342704
#
#    iscritti_aa_2013_2014            ...              iscritti_aa_2010_2011  \
# 0                  14786            ...                            15758.0
# 1                  20968            ...                            23743.0
# 2                  34982            ...                            38036.0
#
#    iscritti_aa_2009_2010  borse_aa_2013_2014  borse_aa_2012_2013  \
# 0                15221.0                1114                 906
# 1                22137.0                1763                1654
# 2                38404.0                2549                2278
#
#    borse_aa_2011_2012  borse_aa_2010_2011  borse_aa_2009_2010      coorY  \
# 0                 614              1069.0              1119.0  45.704354
# 1                1400              2181.0              2401.0  45.187108
# 2                1817              2101.0              2865.0  45.463075
#
#       coorX                   location
# 0  9.660394  (45.70435374, 9.66039439)
# 1  9.155920      (45.1871083, 9.15592)
# 2  9.176896  (45.46307478, 9.17689589)
#
# [3 rows x 22 columns]

# %% [markdown]
# La colonna `RETTORE_DIRETTORE` può contenere valori mancanti, come possiamo vedere di seguito:

# %%
istituti.iloc[12:15]
# Out:
#                                      DENOMINAZIONE   RETTORE_DIRETTORE  \
# 12  ACCADEMIA DI BELLE ARTI SANTA GIULIA - BRESCIA  Riccardo Romagnoli
# 13                    ACCADEMIA L.A.B.A. - BRESCIA  Roberto Dolzanelli
# 14        ACCADEMIA DI BELLE ARTI "A.GALLI" - COMO                 NaN
#
#             INDIRIZZO    CAP   COMUNE  CIVICO  \
# 12    Via N. Tommaseo  25128  Brescia      49
# 13  Via Don G. Vender  25128  Brescia      66
# 14       Via Petrarca  22100     Como       9
#
#                                 EMAIL      TELEFONO         FAX  \
# 12  direzione@accademiasantagiulia.it    030.383368  0303389557
# 13                      info@laba.edu    030.380894  0303391503
# 14            info@accademiagalli.com  031.30.14.30   031302418
#
#     iscritti_aa_2013_2014             ...              iscritti_aa_2010_2011  \
# 12                    652             ...                              525.0
# 13                    791             ...                              744.0
# 14                    131             ...                               76.0
#
#     iscritti_aa_2009_2010  borse_aa_2013_2014  borse_aa_2012_2013  \
# 12                  474.0                  11                  10
# 13                  650.0                  27                  29
# 14                   58.0                   1                   1
#
#     borse_aa_2011_2012  borse_aa_2010_2011  borse_aa_2009_2010      coorY  \
# 12                  10                 7.0                31.0  45.551205
# 13                  30                25.0                53.0  45.559780
# 14                   1                 1.0                 2.0  45.806178
#
#         coorX                    location
# 12  10.213958  (45.55120497, 10.21395831)
# 13  10.203186  (45.55978042, 10.20318641)
# 14   9.092173   (45.80617779, 9.09217337)
#
# [3 rows x 22 columns]

# %% [markdown]
# ## Estrarre le righe con valori mancanti

# %% [markdown]
# Per individuare le righe dove sono presenti valori mancanti esiste la funzione `isnull`, che può essere combinata con un fancy indexing per estrarre le righe con il valore mancante.

# %%
istituti[istituti['RETTORE_DIRETTORE'].isnull()]
# Out:
#                                         DENOMINAZIONE RETTORE_DIRETTORE  \
# 14           ACCADEMIA DI BELLE ARTI "A.GALLI" - COMO               NaN
# 25  SCUOLA SUPERIORE PER MEDIATORI LINGUISTICI SOC...               NaN
# 26  SCUOLA SUPERIORE PER MEDIATORI LINGUISTICI "CA...               NaN
# 27  SCUOLA SUPERIORE PER MEDIATORI LINGUISTICI - V...               NaN
# 29                     ISTITUTO EUROPEO di DESIGN IED               NaN
#
#              INDIRIZZO    CAP  COMUNE  CIVICO                     EMAIL  \
# 14        Via Petrarca  22100    Como       9   info@accademiagalli.com
# 25         Via Daverio  20122  Milano       7  umanitaria@umanitaria.it
# 26  Via Simone Martini  20143  Milano      23    sede.mi@ssmlcarlobo.it
# 27          Via Cavour  21100  Varese      30  direzione@ssml-varese.it
# 29  Via Amatore Sciesa  20135  Milano       4                       NaN
#
#           TELEFONO          FAX  iscritti_aa_2013_2014  \
# 14    031.30.14.30    031302418                    131
# 25      02.5796831    025111846                     29
# 26  02.81.80.85.55   0281808527                    703
# 27     0332.237304   0332240455                    140
# 29      02 5796951  02 55012613                   2906
#
#               ...              iscritti_aa_2010_2011  iscritti_aa_2009_2010  \
# 14            ...                               76.0                   58.0
# 25            ...                               22.0                   17.0
# 26            ...                              556.0                  459.0
# 27            ...                              125.0                  125.0
# 29            ...                                NaN                    NaN
#
#     borse_aa_2013_2014  borse_aa_2012_2013  borse_aa_2011_2012  \
# 14                   1                   1                   1
# 25                   0                   0                   0
# 26                  26                  17                  19
# 27                   8                  15                  13
# 29                  19                  12                  13
#
#     borse_aa_2010_2011  borse_aa_2009_2010      coorY     coorX  \
# 14                 1.0                 2.0  45.806178  9.092173
# 25                 2.0                 1.0  45.459202  9.200738
# 26                23.0                34.0  45.440372  9.159492
# 27                14.0                 9.0  45.819181  8.829511
# 29                 NaN                 NaN  45.461668  9.209483
#
#                      location
# 14  (45.80617779, 9.09217337)
# 25   (45.4592021, 9.20073839)
# 26     (45.440372, 9.1594924)
# 27  (45.81918135, 8.82951075)
# 29  (45.46166838, 9.20948291)
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Ancora dati mancanti
#
# Normalmente valori mancanti rappresentano un'informazione, sebbe parziale: l'assenza di un dato oppure la non conoscenza di un'informazione.
# Per questo motivo i valori mancanti vengono mantenuti (anche se bisogna sempre controllare che non siano dovuti ad errori in fase di importazione dei dati).
#
# Nei rari casi in cui si voglia invece rimuovere le righe con valori mancanti si può utilizzare il metodo `dropna` che verrà spiegato più avanti.
#
# ### Date o timestamp mancanti
#
# Mentre un numero mancante viene rappresentato dalla stringa `NaN` (not a number), nel caso di dati di tipo data o timestamp, il valore mancante viene rappresentato da `NaT` (not a timestamp).

# %% [markdown]
# ## Operazioni e funzioni su DataFrame
#
# Per creare una nuova colonna a partire da altre colonne è sufficiente scrivere l'operazione fra le singole colonne coinvolte.

# %%
artisti['età'] = artisti['yearOfDeath'] - artisti['yearOfBirth']
artisti.head(3)
# Out:
#                        name gender      dates  yearOfBirth  yearOfDeath  \
# id
# 0       Abbey, Edwin Austin   Male  1852–1911       1852.0       1911.0
# 1    Abbott, Lemuel Francis   Male  1760–1803       1760.0       1803.0
# 2   Agasse, Jacques Laurent   Male  1767–1849       1767.0       1849.0
#
#                       placeOfBirth            placeOfDeath   età
# id
# 0      Philadelphia, United States  London, United Kingdom  59.0
# 1   Leicestershire, United Kingdom  London, United Kingdom  43.0
# 2                  Genève, Schweiz  London, United Kingdom  82.0

# %% [markdown]
# Bisogna ricordarsi che ogni operazione in cui un operando è mancante ha un risultato che è a sua volta mancante, come è possibile vedere nell'esempio che segue.

# %%
artisti.loc[621:624]
# Out:
#                       name gender      dates  yearOfBirth  yearOfDeath  \
# id
# 621  Zuccarelli, Francesco   Male  1702–1788       1702.0       1788.0
# 622         Abrahams, Ivor   Male  born 1935       1935.0          NaN
# 623          Acconci, Vito   Male  born 1940       1940.0          NaN
# 624         Ackling, Roger   Male  1947–2014       1947.0       2014.0
#
#                   placeOfBirth placeOfDeath   età
# id
# 621                     Italia      Firenze  86.0
# 622      Wigan, United Kingdom          NaN   NaN
# 623    New York, United States          NaN   NaN
# 624  Isleworth, United Kingdom          NaN  67.0

# %% [markdown]
# ## Funzioni su DataFrame
#
# Alcuni metodi possono essere applicati ad una colonna di DataFrame o una Serie. Le principali sono:
#
# *  `mean()` calcola il valore medio
# *  `median()` calcola il valore mediano
# *  `sum()`  calcola la somma
# *  `size()` calcola il numero di elementi dei gruppi
# *  `count()` calcola il numero di elementi non mancanti nei gruppi
# *  `min()` calcola il minimo valore di ogni gruppo
# *  `max()` calcola il massimo valore di ogni gruppo

# %%
artisti['età'].min()
# Out:
# 0.0

# %% [markdown]
# I metodi possono essere applicati anche ad un intero DataFrame. In questo caso il metodo viene applicato a tutte le colonne che contengono valori numerici.

# %%
artisti.max()
# Out:
# name           Štyrský, Jindrich
# yearOfBirth                 2004
# yearOfDeath                 2014
# età                          199
# dtype: object
