# %%
import pandas as pd

# %% [markdown]
# I questa lezione utilizzeremo alcuni dati provenienti dal [Prezzario dei Lavori Pubblici della Toscana](http://dati.toscana.it/dataset/prezzario-lavori-pubblici).

# %%
gare_no = pd.read_csv("data/scpgarenonaggnew.csv.bz2")
gare_no.head(1)
# Out:
#    id_gara                                 oggetto_della_gara  \
# 0    41762  ID13FAR001/3 procedura negoziata ai sensi art....
#
#   numero_gara_anac    settore  \
# 0              "0"  Ordinario
#
#                               modalita_realizzazione  importo_gara  \
# 0  Contratto di concessione di servizi e/o forniture   23345484.14
#
#    num_tot_lotti                 rup            cf_rup  \
# 0              1  MANIAGO ANNA MARIA  MNGNMR54L43A456Z
#
#   codice_fiscale_stazione_appaltante  \
# 0                      "02801630308"
#
#                          ...                         classifica  \
# 0                        ...                                NaN
#
#   luogo_esecuzione_istat luogo_esecuzione_nuts num_ordine  \
# 0              6000000.0                   NaN          1
#
#                              tipo_atto_o_documento  \
# 0  Provvedimento di gara non aggiudicata o deserta
#
#            data_pubblicazione  data_provvedimento num_provvedimento  \
# ...

# %%
bandi = pd.read_csv("data/scpbandinew.csv.bz2")
bandi.head(1)
# Out:
#    id_gara                                 oggetto_della_gara  \
# 0    59433  Recupero dell'immobile di proprietà comunale d...
# 1    59434  Realizzazione del collettore fognario e impian...
# 2    59435  Ristrutturazione Cimitero nella frazione di Cà...
# 3    59436  TELEPOSTO MONTE SETTEPANI  - MIGLIORAMENTO DEL...
# 4    59437  CIMA PAGANELLA - RISTRUTTURAZIONE STAZIONE MET...
#
#   numero_gara_anac settore modalita_realizzazione  importo_gara  \
# 0              "0"     NaN                    NaN     381544.90
# 1              "0"     NaN                    NaN     748862.50
# 2              "0"     NaN                    NaN     275241.04
# 3              "0"     NaN                    NaN     184375.11
# 4              "0"     NaN                    NaN     149772.50
#
#    num_tot_lotti               rup            cf_rup  \
# 0              1               NaN               NaN
# 1              1               NaN               NaN
# ...

# %%
esiti = pd.read_csv("data/scpesitinew.csv.bz2")
esiti.head(1)
# Out:
#    id_gara                                 oggetto_della_gara  \
# 0    40607  Affidamento dei servizi di manutenzione evolut...
# 1    40608  lavori di Ristrutturazione Edilizia Edificio S...
# 2    40609  Servizio di repertimento e collocamento di per...
# 3    40610  FORNITURA ANNUALE DEL NUOVO FARMACO ?CYRAMZA? ...
# 4    40611  PROCEDURA EX ART. 57, COMMA 2 LETTERA b)  D.LG...
#
#   numero_gara_anac    settore  \
# 0              "0"  Ordinario
# 1              "0"  Ordinario
# 2              "0"  Ordinario
# 3              "0"  Ordinario
# 4              "0"  Ordinario
#
#                               modalita_realizzazione  importo_gara  \
# 0  Contratto di concessione di servizi e/o forniture      92739.00
# 1                                Contratto d'appalto     626991.12
# 2  Contratto di concessione di servizi e/o forniture     250000.00
# 3  Contratto di concessione di servizi e/o forniture     346560.00
# ...

# %%
bandi.head()
# Out:
#    id_gara                                 oggetto_della_gara  \
# 0    59433  Recupero dell'immobile di proprietà comunale d...
# 1    59434  Realizzazione del collettore fognario e impian...
# 2    59435  Ristrutturazione Cimitero nella frazione di Cà...
# 3    59436  TELEPOSTO MONTE SETTEPANI  - MIGLIORAMENTO DEL...
# 4    59437  CIMA PAGANELLA - RISTRUTTURAZIONE STAZIONE MET...
#
#   numero_gara_anac settore modalita_realizzazione  importo_gara  \
# 0              "0"     NaN                    NaN     381544.90
# 1              "0"     NaN                    NaN     748862.50
# 2              "0"     NaN                    NaN     275241.04
# 3              "0"     NaN                    NaN     184375.11
# 4              "0"     NaN                    NaN     149772.50
#
#    num_tot_lotti               rup            cf_rup  \
# 0              1               NaN               NaN
# 1              1               NaN               NaN
# ...

# %% [markdown]
# ## Fondere DataFrame
#
# Il campo `id_gara` permette di incrociare i dati presenti nei tre DataFrame. L'istruzione `merge` permette di fondere due DataFrame.

# %%
fusione = pd.merge(bandi, esiti, on = 'id_gara')
fusione.head()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-8-5c0b790ba4b4> in <module>
# ----> 1 fusione = pd.merge(bandi, esiti, on = 'id_gara')
#       2 fusione.head()
#
# ~/.miniconda/lib/python3.6/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      60                          copy=copy, indicator=indicator,
#      61                          validate=validate)
# ---> 62     return op.get_result()
#      63
#      64
#
# ~/.miniconda/lib/python3.6/site-packages/pandas/core/reshape/merge.py in get_result(self)
#     580             [(ldata, lindexers), (rdata, rindexers)],
#     581             axes=[llabels.append(rlabels), join_index],
# --> 582             concat_axis=0, copy=self.copy)
#     583
#     584         typ = self.left._constructor
#
# ...
